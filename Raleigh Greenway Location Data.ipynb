# %% [markdown]
# ## Import tools

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

# %% [markdown]
# ## Import Greenway data

# %%
df_trails = pd.read_csv('Raleigh_Greenway_Trails.csv')

# %%
df_trails.head()
# Out:
#    OBJECTID   TYPE           LOCATION    STATUS  ST_ID MATERIAL  MAP_MILES  \
# 0         1  Trail    Wakefield Trail  Existing    NaN   Gravel   0.172757
# 1         2  Trail    Wakefield Trail  Existing    NaN  Asphalt   0.341006
# 2         3  Trail    Wakefield Trail  Existing    NaN  Asphalt   0.292243
# 3         4  Trail    Wakefield Trail  Existing    NaN  Asphalt   0.488144
# 4         5  Trail  Neuse River Trail  Existing    NaN  Asphalt   1.182361
#
#    WIDTH_FT ST_TYPE  ST_TONAGE         TRAIL_NAME OWNER  ADA GWSTATUS  \
# 0       5.0     NaN        0.0    Wakefield Trail   COR   NO     OPEN
# 1       8.0     NaN        0.0    Wakefield Trail   COR   NO     OPEN
# 2       8.0     NaN        0.0    Wakefield Trail   COR   NO     OPEN
# 3       8.0     NaN        0.0    Wakefield Trail   COR   NO     OPEN
# 4      10.0     NaN        0.0  Neuse River Trail   COR  YES     OPEN
#
#    TRAILHEAD_ID                                GlobalID  SHAPE_Length
# 0         377.0  {45389098-0B82-4D7B-8057-863682761013}      0.002528
# 1         375.0  {66E2A40F-F8A0-43B3-A5A5-6ADF833BFDAD}      0.005148
# 2         373.0  {EBA4A486-62FD-4A2D-A16C-EA3BF44F5DD9}      0.004544
# 3         374.0  {8FE6EBC5-5196-4E72-A417-41702F96E137}      0.007528
# 4         299.0  {BA2FB4A0-8E35-4F6F-9A43-7457B21E5531}      0.018560

# %%
df_trails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OBJECTID      1260 non-null   int64
#  1   TYPE          1260 non-null   object
#  2   LOCATION      1258 non-null   object
#  3   STATUS        1260 non-null   object
#  4   ST_ID         366 non-null    float64
#  5   MATERIAL      1258 non-null   object
#  6   MAP_MILES     1255 non-null   float64
#  7   WIDTH_FT      1245 non-null   float64
#  8   ST_TYPE       413 non-null    object
#  9   ST_TONAGE     1132 non-null   float64
#  10  TRAIL_NAME    1256 non-null   object
#  11  OWNER         1260 non-null   object
#  12  ADA           1231 non-null   object
#  13  GWSTATUS      1260 non-null   object
#  14  TRAILHEAD_ID  1251 non-null   float64
#  15  GlobalID      1260 non-null   object
#  16  SHAPE_Length  1260 non-null   float64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 167.5+ KB

# %% [markdown]
# ## Import geographic data for Greenways

# %%
df_geo_cords = gpd.read_file('Raleigh_Greenway_Trails.geojson')

# %%
df_geo_cords.head()
# Out:
#    OBJECTID   TYPE           LOCATION    STATUS ST_ID MATERIAL  MAP_MILES  \
# 0         1  Trail    Wakefield Trail  Existing    NA   Gravel   0.172757
# 1         2  Trail    Wakefield Trail  Existing    NA  Asphalt   0.341006
# 2         3  Trail    Wakefield Trail  Existing    NA  Asphalt   0.292243
# 3         4  Trail    Wakefield Trail  Existing    NA  Asphalt   0.488144
# 4         5  Trail  Neuse River Trail  Existing    NA  Asphalt   1.182361
#
#    WIDTH_FT ST_TYPE  ST_TONAGE         TRAIL_NAME OWNER  ADA GWSTATUS  \
# 0       5.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 1       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 2       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 3       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 4      10.0      NA        0.0  Neuse River Trail   COR  YES     OPEN
#
#   TRAILHEAD_ID                                GlobalID  SHAPE_Length  \
# 0          377  {45389098-0B82-4D7B-8057-863682761013}      0.002528
# 1          375  {66E2A40F-F8A0-43B3-A5A5-6ADF833BFDAD}      0.005148
# 2          373  {EBA4A486-62FD-4A2D-A16C-EA3BF44F5DD9}      0.004544
# 3          374  {8FE6EBC5-5196-4E72-A417-41702F96E137}      0.007528
# 4          299  {BA2FB4A0-8E35-4F6F-9A43-7457B21E5531}      0.018560
#
#                                             geometry
# 0  MULTILINESTRING ((-78.55669 35.94597, -78.5566...
# 1  MULTILINESTRING ((-78.55713 35.95301, -78.5571...
# 2  MULTILINESTRING ((-78.55612 35.95444, -78.5561...
# 3  MULTILINESTRING ((-78.55878 35.95808, -78.5587...
# 4  MULTILINESTRING ((-78.55887 35.93057, -78.5588...

# %%
df_geo_cords.columns
# Out:
# Index(['OBJECTID', 'TYPE', 'LOCATION', 'STATUS', 'ST_ID', 'MATERIAL',
#        'MAP_MILES', 'WIDTH_FT', 'ST_TYPE', 'ST_TONAGE', 'TRAIL_NAME', 'OWNER',
#        'ADA', 'GWSTATUS', 'TRAILHEAD_ID', 'GlobalID', 'SHAPE_Length',
#        'geometry'],
#       dtype='object')

# %%
## This line of code helpfully provided by the instructor -- thank you!
df_geo_cords['points'] = df_geo_cords.geometry.apply(lambda x: [y for y in x[0].coords])
# Out:
# /var/folders/9b/ptk_z8b16gl93l2b679w97q40000gn/T/ipykernel_13231/2743568008.py:1: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   df_geo_cords['points'] = df_geo_cords.geometry.apply(lambda x: [y for y in x[0].coords])

# %%
df_geo_cords.head()
# Out:
#    OBJECTID   TYPE           LOCATION    STATUS ST_ID MATERIAL  MAP_MILES  \
# 0         1  Trail    Wakefield Trail  Existing    NA   Gravel   0.172757
# 1         2  Trail    Wakefield Trail  Existing    NA  Asphalt   0.341006
# 2         3  Trail    Wakefield Trail  Existing    NA  Asphalt   0.292243
# 3         4  Trail    Wakefield Trail  Existing    NA  Asphalt   0.488144
# 4         5  Trail  Neuse River Trail  Existing    NA  Asphalt   1.182361
#
#    WIDTH_FT ST_TYPE  ST_TONAGE         TRAIL_NAME OWNER  ADA GWSTATUS  \
# 0       5.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 1       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 2       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 3       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 4      10.0      NA        0.0  Neuse River Trail   COR  YES     OPEN
#
#   TRAILHEAD_ID                                GlobalID  SHAPE_Length  \
# 0          377  {45389098-0B82-4D7B-8057-863682761013}      0.002528
# 1          375  {66E2A40F-F8A0-43B3-A5A5-6ADF833BFDAD}      0.005148
# 2          373  {EBA4A486-62FD-4A2D-A16C-EA3BF44F5DD9}      0.004544
# 3          374  {8FE6EBC5-5196-4E72-A417-41702F96E137}      0.007528
# 4          299  {BA2FB4A0-8E35-4F6F-9A43-7457B21E5531}      0.018560
#
#                                             geometry  \
# 0  MULTILINESTRING ((-78.55669 35.94597, -78.5566...
# 1  MULTILINESTRING ((-78.55713 35.95301, -78.5571...
# 2  MULTILINESTRING ((-78.55612 35.95444, -78.5561...
# 3  MULTILINESTRING ((-78.55878 35.95808, -78.5587...
# 4  MULTILINESTRING ((-78.55887 35.93057, -78.5588...
#
#                                               points
# 0  [(-78.55669199699997, 35.945966533000046), (-7...
# 1  [(-78.55713309899994, 35.953010773000074), (-7...
# 2  [(-78.55612187099996, 35.95444397700004), (-78...
# 3  [(-78.55878455799996, 35.95808245000006), (-78...
# 4  [(-78.55887391699997, 35.930570887000044), (-7...

# %%
##df_geo_cords['avg']=df_geo_cords.points.apply(lambda x: (np.mean(x[0][0]+x[-1][0]),np.mean(x[0][1]+x[-1][1])))

# %%
## Get the first latitude/longitude pair listed for each row
df_geo_cords['first'] = df_geo_cords.points.apply(lambda x: x[0])

# %%
df_geo_cords.head()
# Out:
#    OBJECTID   TYPE           LOCATION    STATUS ST_ID MATERIAL  MAP_MILES  \
# 0         1  Trail    Wakefield Trail  Existing    NA   Gravel   0.172757
# 1         2  Trail    Wakefield Trail  Existing    NA  Asphalt   0.341006
# 2         3  Trail    Wakefield Trail  Existing    NA  Asphalt   0.292243
# 3         4  Trail    Wakefield Trail  Existing    NA  Asphalt   0.488144
# 4         5  Trail  Neuse River Trail  Existing    NA  Asphalt   1.182361
#
#    WIDTH_FT ST_TYPE  ST_TONAGE         TRAIL_NAME OWNER  ADA GWSTATUS  \
# 0       5.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 1       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 2       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 3       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 4      10.0      NA        0.0  Neuse River Trail   COR  YES     OPEN
#
#   TRAILHEAD_ID                                GlobalID  SHAPE_Length  \
# 0          377  {45389098-0B82-4D7B-8057-863682761013}      0.002528
# 1          375  {66E2A40F-F8A0-43B3-A5A5-6ADF833BFDAD}      0.005148
# 2          373  {EBA4A486-62FD-4A2D-A16C-EA3BF44F5DD9}      0.004544
# 3          374  {8FE6EBC5-5196-4E72-A417-41702F96E137}      0.007528
# 4          299  {BA2FB4A0-8E35-4F6F-9A43-7457B21E5531}      0.018560
#
#                                             geometry  \
# 0  MULTILINESTRING ((-78.55669 35.94597, -78.5566...
# 1  MULTILINESTRING ((-78.55713 35.95301, -78.5571...
# 2  MULTILINESTRING ((-78.55612 35.95444, -78.5561...
# 3  MULTILINESTRING ((-78.55878 35.95808, -78.5587...
# 4  MULTILINESTRING ((-78.55887 35.93057, -78.5588...
#
#                                               points  \
# 0  [(-78.55669199699997, 35.945966533000046), (-7...
# 1  [(-78.55713309899994, 35.953010773000074), (-7...
# 2  [(-78.55612187099996, 35.95444397700004), (-78...
# 3  [(-78.55878455799996, 35.95808245000006), (-78...
# 4  [(-78.55887391699997, 35.930570887000044), (-7...
#
#                                       first
# 0  (-78.55669199699997, 35.945966533000046)
# 1  (-78.55713309899994, 35.953010773000074)
# 2   (-78.55612187099996, 35.95444397700004)
# 3   (-78.55878455799996, 35.95808245000006)
# 4  (-78.55887391699997, 35.930570887000044)

# %%
df_geo_cords.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OBJECTID      1260 non-null   int64
#  1   TYPE          1260 non-null   object
#  2   LOCATION      1258 non-null   object
#  3   STATUS        1260 non-null   object
#  4   ST_ID         1248 non-null   object
#  5   MATERIAL      1259 non-null   object
#  6   MAP_MILES     1255 non-null   float64
#  7   WIDTH_FT      1245 non-null   float64
#  8   ST_TYPE       1234 non-null   object
#  9   ST_TONAGE     1132 non-null   float64
#  10  TRAIL_NAME    1258 non-null   object
#  11  OWNER         1260 non-null   object
#  12  ADA           1231 non-null   object
#  13  GWSTATUS      1260 non-null   object
#  14  TRAILHEAD_ID  1251 non-null   object
#  15  GlobalID      1260 non-null   object
#  16  SHAPE_Length  1260 non-null   float64
#  17  geometry      1260 non-null   geometry
#  18  points        1260 non-null   object
#  19  first         1260 non-null   object
# dtypes: float64(4), geometry(1), int64(1), object(14)
# memory usage: 197.0+ KB

# %%
## Playing with a different way to get lat/long
df_geo_cords['latitude'] = df_geo_cords.points.apply(lambda x: x[0][0])

# %%
df_geo_cords.latitude.head()
# Out:
# 0   -78.556692
# 1   -78.557133
# 2   -78.556122
# 3   -78.558785
# 4   -78.558874
# Name: latitude, dtype: float64

# %%
df_geo_cords['longitude'] = df_geo_cords.points.apply(lambda x: x[0][-1])

# %%
df_geo_cords.longitude.head()
# Out:
# 0    35.945967
# 1    35.953011
# 2    35.954444
# 3    35.958082
# 4    35.930571
# Name: longitude, dtype: float64

# %%
#df_geo_cords.drop('geometry', axis = 1, inplace = True)
df_geo_cords.drop('points', axis = 1, inplace = True)
df_geo_cords.head()
# Out:
#    OBJECTID   TYPE           LOCATION    STATUS ST_ID MATERIAL  MAP_MILES  \
# 0         1  Trail    Wakefield Trail  Existing    NA   Gravel   0.172757
# 1         2  Trail    Wakefield Trail  Existing    NA  Asphalt   0.341006
# 2         3  Trail    Wakefield Trail  Existing    NA  Asphalt   0.292243
# 3         4  Trail    Wakefield Trail  Existing    NA  Asphalt   0.488144
# 4         5  Trail  Neuse River Trail  Existing    NA  Asphalt   1.182361
#
#    WIDTH_FT ST_TYPE  ST_TONAGE         TRAIL_NAME OWNER  ADA GWSTATUS  \
# 0       5.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 1       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 2       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 3       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 4      10.0      NA        0.0  Neuse River Trail   COR  YES     OPEN
#
#   TRAILHEAD_ID                                GlobalID  SHAPE_Length  \
# 0          377  {45389098-0B82-4D7B-8057-863682761013}      0.002528
# 1          375  {66E2A40F-F8A0-43B3-A5A5-6ADF833BFDAD}      0.005148
# 2          373  {EBA4A486-62FD-4A2D-A16C-EA3BF44F5DD9}      0.004544
# 3          374  {8FE6EBC5-5196-4E72-A417-41702F96E137}      0.007528
# 4          299  {BA2FB4A0-8E35-4F6F-9A43-7457B21E5531}      0.018560
#
#                                       first   latitude  longitude
# 0  (-78.55669199699997, 35.945966533000046) -78.556692  35.945967
# 1  (-78.55713309899994, 35.953010773000074) -78.557133  35.953011
# 2   (-78.55612187099996, 35.95444397700004) -78.556122  35.954444
# 3   (-78.55878455799996, 35.95808245000006) -78.558785  35.958082
# 4  (-78.55887391699997, 35.930570887000044) -78.558874  35.930571

# %%
## Looking at total length in miles of each trail as identified by Trail Name
grouped = df_geo_cords.groupby('TRAIL_NAME').MAP_MILES.sum()

# %%
grouped
# Out:
# TRAIL_NAME
# Abbotts Creek Trail              3.258291
# Baileywick Trail                 0.598456
# Beaver Dam Trail                 1.172190
# Birch Ridge Connector            0.319910
# Centennial Bikeway Connector     1.579755
# Crabtree Creek Trail            16.976546
# East Fork Mine Creek Trail       2.508360
# Edwards Mill Connector           1.327959
# Gardner Street Trail             0.764088
# Hare Snipe Creek Trail           3.740996
# Honeycutt Creek Trail            3.814529
# House Creek Trail                3.238115
# Little Rock Trail                1.776653
# Marsh Creek Trail                0.352761
# Martin St Connector              0.442487
# Mine Creek Trail                 6.919707
# NA                               0.082335
# Neuse River Trail               33.265445
# Reedy Creek Trail                5.890294
# Richland Creek Trail             3.020076
# Rocky Branch Trail               3.875173
# Rocky Branch Trail Extension     0.670209
# Simms Branch Trail               1.852912
# Snelling Branch Trail            0.847780
# Spring Forest Trail              0.444277
# Wakefield Trail                  1.434000
# Walnut Creek Trail              20.569158
# Name: MAP_MILES, dtype: float64

# %%
#df_geo_cords.to_csv('Raleigh_Greenway_location_data.csv')

# %% [markdown]
# ## Import ZIP code geographic data

# %%
df_zips = gpd.read_file('Zip_Codes.geojson')

# %%
df_zips.head()
# Out:
#    OBJECTID      ZIPNAME   ZIPNUM            ZIPCODE         NAME  \
# 0      8385      RALEIGH  27601.0      RALEIGH 27601      RALEIGH
# 1      8386       DURHAM  27713.0       DURHAM 27713       DURHAM
# 2      8387      RALEIGH  27604.0      RALEIGH 27604      RALEIGH
# 3      8388  WAKE FOREST  27587.0  WAKE FOREST 27587  WAKE FOREST
# 4      8389       DURHAM  27703.0       DURHAM 27703       DURHAM
#
#             LAST_EDITED_DATE     SHAPEAREA       SHAPELEN  \
# 0                       None  5.075530e+07   43034.538745
# 1                       None  9.440600e+06   22633.644539
# 2                       None  5.678501e+08  201307.097948
# 3  2017-10-25T15:38:04+00:00  2.686573e+09  563409.944946
# 4                       None  5.768992e+06   22448.009933
#
#                                             geometry
# 0  POLYGON ((-78.62613 35.76635, -78.62614 35.766...
# 1  POLYGON ((-78.89707 35.86367, -78.89689 35.863...
# 2  POLYGON ((-78.55749 35.79948, -78.55748 35.799...
# 3  POLYGON ((-78.67821 35.98801, -78.67846 35.989...
# 4  POLYGON ((-78.79667 35.92592, -78.79732 35.926...

# %%
df_zips.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OBJECTID          68 non-null     int64
#  1   ZIPNAME           57 non-null     object
#  2   ZIPNUM            57 non-null     float64
#  3   ZIPCODE           57 non-null     object
#  4   NAME              57 non-null     object
#  5   LAST_EDITED_DATE  21 non-null     object
#  6   SHAPEAREA         68 non-null     float64
#  7   SHAPELEN          68 non-null     float64
#  8   geometry          68 non-null     geometry
# dtypes: float64(3), geometry(1), int64(1), object(4)
# memory usage: 4.9+ KB

# %%
## drop duplicates
df_zips.dropna(subset = ['ZIPNUM'], inplace = True)

# %%
df_zips.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 57 entries, 0 to 67
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OBJECTID          57 non-null     int64
#  1   ZIPNAME           57 non-null     object
#  2   ZIPNUM            57 non-null     float64
#  3   ZIPCODE           57 non-null     object
#  4   NAME              57 non-null     object
#  5   LAST_EDITED_DATE  21 non-null     object
#  6   SHAPEAREA         57 non-null     float64
#  7   SHAPELEN          57 non-null     float64
#  8   geometry          57 non-null     geometry
# dtypes: float64(3), geometry(1), int64(1), object(4)
# memory usage: 4.5+ KB

# %%
## Change type of column containing ZIP codes from object to interger
df_zips.astype({'ZIPNUM': 'int64'}, copy = False).dtypes
# Out:
# OBJECTID               int64
# ZIPNAME               object
# ZIPNUM                 int64
# ZIPCODE               object
# NAME                  object
# LAST_EDITED_DATE      object
# SHAPEAREA            float64
# SHAPELEN             float64
# geometry            geometry
# dtype: object

# %%
## Finding rows with ZIP of 27614, which the test point Point(-78.55669199699997, 35.945966533000046) belongs inside.
df_zips[df_zips['ZIPNUM'] == 27614]
# Out:
#     OBJECTID  ZIPNAME   ZIPNUM        ZIPCODE     NAME  \
# 27      8412  RALEIGH  27614.0  RALEIGH 27614  RALEIGH
# 39      8424  RALEIGH  27614.0  RALEIGH 27614  RALEIGH
#
#              LAST_EDITED_DATE     SHAPEAREA       SHAPELEN  \
# 27  2018-01-22T13:33:47+00:00  8.195607e+08  227392.627645
# 39  2017-05-17T08:54:53+00:00  3.920281e+06    8610.262893
#
#                                              geometry
# 27  POLYGON ((-78.66499 36.00044, -78.66521 36.000...
# 39  POLYGON ((-78.67795 35.98802, -78.67796 35.988...

# %%
## Shapely code adapted from Stackoverflow
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

point = Point(-78.55669199699997, 35.945966533000046)
polygon = df_zips.loc[27, 'geometry']
print(polygon.contains(point))
## 27614
# Out:
# True

# %%
df_geo_cords.head()
# Out:
#    OBJECTID   TYPE           LOCATION    STATUS ST_ID MATERIAL  MAP_MILES  \
# 0         1  Trail    Wakefield Trail  Existing    NA   Gravel   0.172757
# 1         2  Trail    Wakefield Trail  Existing    NA  Asphalt   0.341006
# 2         3  Trail    Wakefield Trail  Existing    NA  Asphalt   0.292243
# 3         4  Trail    Wakefield Trail  Existing    NA  Asphalt   0.488144
# 4         5  Trail  Neuse River Trail  Existing    NA  Asphalt   1.182361
#
#    WIDTH_FT ST_TYPE  ST_TONAGE         TRAIL_NAME OWNER  ADA GWSTATUS  \
# 0       5.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 1       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 2       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 3       8.0      NA        0.0    Wakefield Trail   COR   NO     OPEN
# 4      10.0      NA        0.0  Neuse River Trail   COR  YES     OPEN
#
#   TRAILHEAD_ID                                GlobalID  SHAPE_Length  \
# 0          377  {45389098-0B82-4D7B-8057-863682761013}      0.002528
# 1          375  {66E2A40F-F8A0-43B3-A5A5-6ADF833BFDAD}      0.005148
# 2          373  {EBA4A486-62FD-4A2D-A16C-EA3BF44F5DD9}      0.004544
# 3          374  {8FE6EBC5-5196-4E72-A417-41702F96E137}      0.007528
# 4          299  {BA2FB4A0-8E35-4F6F-9A43-7457B21E5531}      0.018560
#
#                                       first   latitude  longitude
# 0  (-78.55669199699997, 35.945966533000046) -78.556692  35.945967
# 1  (-78.55713309899994, 35.953010773000074) -78.557133  35.953011
# 2   (-78.55612187099996, 35.95444397700004) -78.556122  35.954444
# 3   (-78.55878455799996, 35.95808245000006) -78.558785  35.958082
# 4  (-78.55887391699997, 35.930570887000044) -78.558874  35.930571

# %%
df_zips.shape
# Out:
# (57, 9)

# %%
## Function that accepts a tuple with latitutde and longitude information as input, converts it to a Point object
## and searches the "geometry" column of the ZIPs dataframe to see if the point is inside each Polygon object. If
## the point is inside a Polygon, the function returns the corresponding ZIP code in the ZIPNUM column.
def get_ZIP(tup):
    x = 0
    point = Point(tup)
    while x < 57:
        polygon = df_zips.loc[x, 'geometry']
        if polygon.contains(point) == True:
            return df_zips.loc[x, 'ZIPNUM']
            break
        else:
            x = x + 1

# %%
## Testing function on a single point (went back and deleted print statements afterwards)
get_ZIP((-78.55669199699997, 35.945966533000046))
# Out:
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# True

# %%
## Apply the function to the column with coordinates to get the ZIP code for each one
df_geo_cords['ZIP'] = df_geo_cords['first'].apply(lambda x: get_ZIP(x))

# %%
df_geo_cords[df_geo_cords['first'].isna()]
# Out:
# Empty DataFrame
# Columns: [OBJECTID, TYPE, LOCATION, STATUS, ST_ID, MATERIAL, MAP_MILES, WIDTH_FT, ST_TYPE, ST_TONAGE, TRAIL_NAME, OWNER, ADA, GWSTATUS, TRAILHEAD_ID, GlobalID, SHAPE_Length, first, latitude, longitude, ZIP]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_zips[df_zips['geometry'].isna()]
# Out:
# Empty GeoDataFrame
# Columns: [OBJECTID, ZIPNAME, ZIPNUM, ZIPCODE, NAME, LAST_EDITED_DATE, SHAPEAREA, SHAPELEN, geometry]
# Index: []

# %%
## check for NULL geometry/polygon
df_geo_cords.head()
# Out:
#    OBJECTID   TYPE           LOCATION    STATUS ST_ID MATERIAL  MAP_MILES  \
# 0         1  Trail    Wakefield Trail  Existing    NA   Gravel   0.172757
# 1         2  Trail    Wakefield Trail  Existing    NA  Asphalt   0.341006
# 2         3  Trail    Wakefield Trail  Existing    NA  Asphalt   0.292243
# 3         4  Trail    Wakefield Trail  Existing    NA  Asphalt   0.488144
# 4         5  Trail  Neuse River Trail  Existing    NA  Asphalt   1.182361
#
#    WIDTH_FT ST_TYPE  ST_TONAGE  ... OWNER  ADA GWSTATUS TRAILHEAD_ID  \
# 0       5.0      NA        0.0  ...   COR   NO     OPEN          377
# 1       8.0      NA        0.0  ...   COR   NO     OPEN          375
# 2       8.0      NA        0.0  ...   COR   NO     OPEN          373
# 3       8.0      NA        0.0  ...   COR   NO     OPEN          374
# 4      10.0      NA        0.0  ...   COR  YES     OPEN          299
#
#                                  GlobalID SHAPE_Length  \
# 0  {45389098-0B82-4D7B-8057-863682761013}     0.002528
# 1  {66E2A40F-F8A0-43B3-A5A5-6ADF833BFDAD}     0.005148
# 2  {EBA4A486-62FD-4A2D-A16C-EA3BF44F5DD9}     0.004544
# 3  {8FE6EBC5-5196-4E72-A417-41702F96E137}     0.007528
# 4  {BA2FB4A0-8E35-4F6F-9A43-7457B21E5531}     0.018560
#
#                                       first   latitude  longitude      ZIP
# 0  (-78.55669199699997, 35.945966533000046) -78.556692  35.945967  27614.0
# 1  (-78.55713309899994, 35.953010773000074) -78.557133  35.953011  27614.0
# 2   (-78.55612187099996, 35.95444397700004) -78.556122  35.954444  27614.0
# 3   (-78.55878455799996, 35.95808245000006) -78.558785  35.958082  27614.0
# 4  (-78.55887391699997, 35.930570887000044) -78.558874  35.930571  27614.0
#
# [5 rows x 21 columns]

# %%
df_geo_cords.ZIP.unique()
# Out:
# array([27614., 27587., 27615., 27616., 27604., 27610., 27612., 27613.,
#        27606., 27607., 27603., 27601., 27609., 27608., 27545., 27617.])

# %%
## Export resulting file to be manipulated in Google Sheets and Tableau
df_geo_cords.to_csv('Raleigh_Greenway_location_data_with_ZIPs.csv')
